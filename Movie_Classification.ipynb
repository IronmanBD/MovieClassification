jpg
#   inflating: input/Multi_Label_dataset/Images/tt3760966.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3767372.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3774466.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3774694.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3781762.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3787590.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3790720.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3794204.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3801934.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3808342.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3812366.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3813310.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3819668.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3824412.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3824458.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3832914.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3836958.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3837248.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3844362.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3848938.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3850214.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3850590.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3859076.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3862750.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3863552.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3868452.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3877296.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3884528.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3890264.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3892618.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3896100.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3906606.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3950078.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3957716.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3962210.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3962848.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3966404.jpg
#   inflating: input/Multi_Label_dataset/Images/tt3993894.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4002772.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4003774.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4007558.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4008348.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4008652.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4034452.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4044364.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4046784.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4047350.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4056738.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4058650.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4074958.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4078160.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4079142.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4094590.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4104022.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4109204.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4126304.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4131188.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4137324.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4145178.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4145304.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4159182.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4179482.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4183692.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4185572.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4188202.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4191054.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4242158.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4248930.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4253360.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4265396.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4273886.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4276752.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4288636.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4294052.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4294084.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4296800.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4316236.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4337072.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4337690.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4344782.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4357170.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4358230.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4377864.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4381862.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4382618.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4382872.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4414694.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4422656.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4425064.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4425148.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4425258.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4430136.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4430992.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4434016.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4462082.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4467262.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4504040.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4505170.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4506722.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4535650.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4568106.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4572856.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4594834.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4610372.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4618398.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4621016.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4643580.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4668808.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4669204.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4692234.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4692242.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4693418.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4695462.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4696222.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4701702.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4727756.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4768764.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4781992.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4819544.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4819560.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4830104.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4836406.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4846028.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4935446.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4936064.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4938602.jpg
#   inflating: input/Multi_Label_dataset/Images/tt4944352.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5022418.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5049302.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5061814.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5105784.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5233460.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5257730.jpg
#   inflating: input/Multi_Label_dataset/Images/tt5503970.jpg
#   inflating: input/Multi_Label_dataset/train.csv

# %%
import pandas as pd

df = pd.read_csv('../content/input/Multi_Label_dataset/train.csv')

# %%
df.head(5)
# Out:
#           Id                                Genre  ...  War  Western
# 0  tt0086425                  ['Comedy', 'Drama']  ...    0        0
# 1  tt0085549        ['Drama', 'Romance', 'Music']  ...    0        0
# 2  tt0086465                           ['Comedy']  ...    0        0
# 3  tt0086567               ['Sci-Fi', 'Thriller']  ...    0        0
# 4  tt0086034  ['Action', 'Adventure', 'Thriller']  ...    0        0
#
# [5 rows x 27 columns]

# %%
# %%writefile dataset.py
import torch
import cv2
import numpy as np
import torchvision.transforms as transforms
from torch.utils.data import Dataset

class MovieDataset(Dataset):
    def __init__(self, csv, train, test):
        self.csv = csv
        self.train = train
        self.test = test
        self.all_image_names = self.csv[:]['Id']
        self.all_labels = np.array(self.csv.drop(['Id', 'Genre'], axis=1))
        self.train_ratio = int(0.85 * len(self.csv))
        self.valid_ratio = len(self.csv) - self.train_ratio
        # set the training data images and labels
        if self.train == True:
            print(f"Number of training images: {self.train_ratio}")
            self.image_names = list(self.all_image_names[:self.train_ratio])
            self.labels = list(self.all_labels[:self.train_ratio])
            # define the training transforms
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.Resize((400, 400)),
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomRotation(degrees=45),
                transforms.ToTensor(),
            ])
        # set the validation data images and labels
        elif self.train == False and self.test == False:
            print(f"Number of validation images: {self.valid_ratio}")
            self.image_names = list(self.all_image_names[-self.valid_ratio:-10])
            self.labels = list(self.all_labels[-self.valid_ratio:])
            # define the validation transforms
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.Resize((400, 400)),
                transforms.ToTensor(),
            ])
        # set the test data images and labels, only last 10 images
        # this, we will use in a separate inference script
        elif self.test == True and self.train == False:
            self.image_names = list(self.all_image_names[-10:])
            self.labels = list(self.all_labels[-10:])
             # define the test transforms
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.ToTensor(),
            ])
    def __len__(self):
        return len(self.image_names)
    
    def __getitem__(self, index):
        image = cv2.imread(f"/content/input/Multi_Label_dataset/Images/{self.image_names[index]}.jpg")
        # convert the image from BGR to RGB color format
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        # apply image transforms
        image = self.transform(image)
        targets = self.labels[index]
        
        return {
            'image': torch.tensor(image, dtype=torch.float32),
            'label': torch.tensor(targets, dtype=torch.float32)
        }
# Out:
# Writing dataset.py

# %%
# %%writefile models.py
from torchvision import models as models
import torch.nn as nn
def model(pretrained, requires_grad):
    model = models.resnet50(progress=True, pretrained=pretrained)
    # to freeze the hidden layers
    if requires_grad == False:
        for param in model.parameters():
            param.requires_grad = False
    # to train the hidden layers
    elif requires_grad == True:
        for param in model.parameters():
            param.requires_grad = True
    # make the classification layer learnable
    # we have 25 classes in total
    model.fc = nn.Linear(2048, 25)
    return model
# Out:
# Writing models.py

# %%
# %%writefile engine.py
import torch
from tqdm import tqdm
# training function
def train(model, dataloader, optimizer, criterion, train_data, device):
    print('Training')
    model.train()
    counter = 0
    train_running_loss = 0.0
    for i, data in tqdm(enumerate(dataloader), total=int(len(train_data)/dataloader.batch_size)):
        counter += 1
        data, target = data['image'].to(device), data['label'].to(device)
        optimizer.zero_grad()
        outputs = model(data)
        # apply sigmoid activation to get all the outputs between 0 and 1
        outputs = torch.sigmoid(outputs)
        loss = criterion(outputs, target)
        train_running_loss += loss.item()
        # backpropagation
        loss.backward()
        # update optimizer parameters
        optimizer.step()
        
    train_loss = train_running_loss / counter
    return train_loss

# validation function
def validate(model, dataloader, criterion, val_data, device):
    print('Validating')
    model.eval()
    counter = 0
    val_running_loss = 0.0
    with torch.no_grad():
        for i, data in tqdm(enumerate(dataloader), total=int(len(val_data)/dataloader.batch_size)):
            counter += 1
            data, target = data['image'].to(device), data['label'].to(device)
            outputs = model(data)
            # apply sigmoid activation to get all the outputs between 0 and 1
            outputs = torch.sigmoid(outputs)
            loss = criterion(outputs, target)
            val_running_loss += loss.item()
        
        val_loss = val_running_loss / counter
        return val_loss
# Out:
# Writing engine.py

# %%
# %%writefile train.py
import models
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from engine import train, validate
from dataset import MovieDataset
from torch.utils.data import DataLoader
matplotlib.style.use('ggplot')
# initialize the computation device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#intialize the model
model = models.model(pretrained=True, requires_grad=False).to(device)
# learning parameters
lr = 0.0001
epochs = 20
batch_size = 32
optimizer = optim.Adam(model.parameters(), lr=lr)
criterion = nn.BCELoss()

# read the training csv file
train_csv = pd.read_csv('/content/input/Multi_Label_dataset/train.csv')
# train dataset
train_data = MovieDataset(
    train_csv, train=True, test=False
)
# validation dataset
valid_data = MovieDataset(
    train_csv, train=False, test=False
)
# train data loader
train_loader = DataLoader(
    train_data, 
    batch_size=batch_size,
    shuffle=True
)
# validation data loader
valid_loader = DataLoader(
    valid_data, 
    batch_size=batch_size,
    shuffle=False
)

# start the training and validation
train_loss = []
valid_loss = []
for epoch in range(epochs):
    print(f"Epoch {epoch+1} of {epochs}")
    train_epoch_loss = train(
        model, train_loader, optimizer, criterion, train_data, device
    )
    valid_epoch_loss = validate(
        model, valid_loader, criterion, valid_data, device
    )
    train_loss.append(train_epoch_loss)
    valid_loss.append(valid_epoch_loss)
    print(f"Train Loss: {train_epoch_loss:.4f}")
    print(f'Val Loss: {valid_epoch_loss:.4f}')


# save the trained model to disk
torch.save({
            'epoch': epochs,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': criterion,
            }, '../content/outputs/model.pth')
# plot and save the train and validation line graphs
plt.figure(figsize=(10, 7))
plt.plot(train_loss, color='orange', label='train loss')
plt.plot(valid_loss, color='red', label='validataion loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('../content/outputs/loss.png')
plt.show()
# Out:
# Writing train.py

# %%
# !python train.py
# Out:
# Number of training images: 6165
# Number of validation images: 1089
# Epoch 1 of 20
# Training
#   0% 0/192 [00:00<?, ?it/s]/content/dataset.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'image': torch.tensor(image, dtype=torch.float32),
# 193it [01:24,  2.27it/s]
# Validating
# 34it [00:13,  2.55it/s]
# Train Loss: 0.2695
# Val Loss: 0.2464
# Epoch 2 of 20
# Training
# 193it [01:25,  2.27it/s]
# Validating
# 34it [00:13,  2.54it/s]
# Train Loss: 0.2331
# Val Loss: 0.2393
# Epoch 3 of 20
# Training
# 193it [01:24,  2.28it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2276
# Val Loss: 0.2342
# Epoch 4 of 20
# Training
# 193it [01:24,  2.29it/s]
# Validating
# 34it [00:13,  2.57it/s]
# Train Loss: 0.2228
# Val Loss: 0.2309
# Epoch 5 of 20
# Training
# 193it [01:24,  2.29it/s]
# Validating
# 34it [00:13,  2.55it/s]
# Train Loss: 0.2194
# Val Loss: 0.2290
# Epoch 6 of 20
# Training
# 193it [01:24,  2.29it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2169
# Val Loss: 0.2264
# Epoch 7 of 20
# Training
# 193it [01:23,  2.30it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2150
# Val Loss: 0.2244
# Epoch 8 of 20
# Training
# 193it [01:24,  2.30it/s]
# Validating
# 34it [00:13,  2.55it/s]
# Train Loss: 0.2132
# Val Loss: 0.2236
# Epoch 9 of 20
# Training
# 193it [01:24,  2.29it/s]
# Validating
# 34it [00:13,  2.55it/s]
# Train Loss: 0.2120
# Val Loss: 0.2256
# Epoch 10 of 20
# Training
# 193it [01:24,  2.29it/s]
# Validating
# 34it [00:13,  2.55it/s]
# Train Loss: 0.2105
# Val Loss: 0.2214
# Epoch 11 of 20
# Training
# 193it [01:25,  2.26it/s]
# Validating
# 34it [00:13,  2.53it/s]
# Train Loss: 0.2091
# Val Loss: 0.2210
# Epoch 12 of 20
# Training
# 193it [01:23,  2.30it/s]
# Validating
# 34it [00:13,  2.57it/s]
# Train Loss: 0.2081
# Val Loss: 0.2198
# Epoch 13 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2079
# Val Loss: 0.2205
# Epoch 14 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2067
# Val Loss: 0.2205
# Epoch 15 of 20
# Training
# 193it [01:23,  2.30it/s]
# Validating
# 34it [00:13,  2.57it/s]
# Train Loss: 0.2064
# Val Loss: 0.2183
# Epoch 16 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.57it/s]
# Train Loss: 0.2060
# Val Loss: 0.2196
# Epoch 17 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.57it/s]
# Train Loss: 0.2048
# Val Loss: 0.2200
# Epoch 18 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2044
# Val Loss: 0.2186
# Epoch 19 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2042
# Val Loss: 0.2189
# Epoch 20 of 20
# Training
# 193it [01:23,  2.31it/s]
# Validating
# 34it [00:13,  2.56it/s]
# Train Loss: 0.2035
# Val Loss: 0.2197
# <Figure size 1000x700 with 1 Axes>

# %%
# %%writefile inference.py
import models
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dataset import MovieDataset
from torch.utils.data import DataLoader

# initialize the computation device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#intialize the model
model = models.model(pretrained=False, requires_grad=False).to(device)
# load the model checkpoint
checkpoint = torch.load('../content/outputs/model.pth')
# load model weights state_dict
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

train_csv = pd.read_csv('../content/input/Multi_Label_dataset/train.csv')
genres = train_csv.columns.values[2:]
# prepare the test dataset and dataloader
test_data = MovieDataset(
    train_csv, train=False, test=True
)
test_loader = DataLoader(
    test_data, 
    batch_size=1,
    shuffle=False
)

for counter, data in enumerate(test_loader):
    image, target = data['image'].to(device), data['label']
    # get all the index positions where value == 1
    target_indices = [i for i in range(len(target[0])) if target[0][i] == 1]
    # get the predictions by passing the image through the model
    outputs = model(image)
    outputs = torch.sigmoid(outputs)
    outputs = outputs.detach().cpu()
    sorted_indices = np.argsort(outputs[0])
    best = sorted_indices[-3:]
    string_predicted = ''
    string_actual = ''
    for i in range(len(best)):
        string_predicted += f"{genres[best[i]]}    "
    for i in range(len(target_indices)):
        string_actual += f"{genres[target_indices[i]]}    "
    image = image.squeeze(0)
    image = image.detach().cpu().numpy()
    image = np.transpose(image, (1, 2, 0))
    plt.imshow(image)
    plt.axis('off')
    plt.title(f"PREDICTED: {string_predicted}\nACTUAL: {string_actual}")
    plt.savefig(f"../content/outputs/inference_{counter}.jpg")
    plt.show()
# Out:
# Overwriting inference.py

# %%
# !python inference.py
# Out:
# /content/dataset.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'image': torch.tensor(image, dtype=torch.float32),
# <Figure size 640x480 with 1 Axes>
# /content/dataset.py:62: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'image': torch.tensor(image, dtype=torch.float32),
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
